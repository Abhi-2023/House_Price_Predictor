# %% [markdown]
# Problem statement
# -----------------
#
# Predict the median house price value in block grp as per data, when going to purchase house.
# ___

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing()

# %% [markdown]
# Understanding the data
# ----------------------
# ________

# %%
data.target
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,))

# %%
print(data.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
print(data.target_names)
# Out:
# ['MedHouseVal']

# %%
df = pd.DataFrame(data=data.data, columns= data.feature_names)

# %%
df['Target'] = data.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Target
# ...

# %%
# Sample check
df.head(20)
# Out:
#     MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0   8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1   8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2   7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3   5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4   3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5   4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6   3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7   3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8   2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9   3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
# 10  3.2031      52.0  5.477612   1.079602       910.0  2.263682     37.85
# 11  3.2705      52.0  4.772480   1.024523      1504.0  2.049046     37.85
# ...

# %%
# What's the data type of features of data frame
df.dtypes
# Out:
# MedInc        float64
# HouseAge      float64
# AveRooms      float64
# AveBedrms     float64
# Population    float64
# AveOccup      float64
# Latitude      float64
# Longitude     float64
# Target        float64
# dtype: object

# %% [markdown]
# Data Preparation
# ----------------
# ______________

# %%
# Checking for null values
df.isna().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# Target        0
# dtype: int64

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude        Target
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
# Correcting the target variable name

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Target
# ...

# %%
df[str(data.target_names[0])] = data.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Target  MedHouseVal
# ...

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Target  MedHouseVal
# ...

# %% [markdown]
# EDA
# ----
# ____

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.corr()
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Target       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude    Target  MedHouseVal
# MedInc      -0.079809  -0.015176  0.688075     0.688075
# ...

# %%
plt.scatter(df.AveBedrms, df.MedHouseVal)
plt.xlabel("Average bedrooms in a household")
plt.ylabel("Price")
plt.show()

# %%
sns.regplot(x=df.MedInc, y=df.MedHouseVal, data=df)
# Out:
# <Axes: xlabel='MedInc', ylabel='MedHouseVal'>

# %%
# Train Test Split

X = df.drop('MedHouseVal', axis=1)
y = df.MedHouseVal

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=1)
X_test.shape, y_test.shape
# Out:
# ((6192, 9), (6192,))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Model Training
# ------
# ________

# %%
# Model before hypertuning

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(f"R2 Score of the best model is : {r2_score(y_test, y_pred=y_pred)}")
# Out:
# R2 Score of the best model is : 1.0

# %%
param_grid = {
    'alpha': [1e-4, 1e-3, 1e-2, 1e-1, 1, 10],
    'l1_ratio': [0.0, 0.25, 0.5, 0.75, 1.0],
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
grid = GridSearchCV(
    estimator=Ridge(),
    param_grid={'alpha': [0.01, 0.1, 1, 10]},
    cv=5
)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(), param_grid={'alpha': [0.01, 0.1, 1, 10]})

# %%
grid.best_params_
# Out:
# {'alpha': 0.01}

# %%
grid.best_score_
# Out:
# np.float64(0.9999999999980496)

# %%
y_pred = grid.best_estimator_.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(f"R2 Score of the best model is : {r2_score(y_test, y_pred=y_pred)}")
# Out:
# R2 Score of the best model is : 0.999999999998733

# %%
# Applying best parameter to final model 
ridge_Model = Ridge(alpha=10)
ridge_Model.fit(X_train, y_train)
# Out:
# Ridge(alpha=10)

# %%
y_pred_regularized = ridge_Model.predict(X_test)

# %%
print(f"R2 Score of the best model is : {r2_score(y_test, y_pred=y_pred_regularized)}")
# Out:
# R2 Score of the best model is : 0.9999987457500185

# %%
residuals = y_test - y_pred_regularized

plt.scatter(y_pred_regularized, residuals)

plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
sns.kdeplot(residuals)
# Out:
# <Axes: xlabel='MedHouseVal', ylabel='Density'>

# %% [markdown]
# Zipping Model
# ----
# ______

# %%
import pickle as pik
pik.dump(ridge_Model, open("house_pred.pkl", 'wb'))

# %%
pik.load(open('house_pred.pkl', 'rb'))
# Out:
# Ridge(alpha=10)
